# %% [markdown]
# ### create data from reading a file

# %%
df = spark.read.format("csv") \
    .option("header",True) \
        .option("inferSchema","true") \
    .load('/Volumes/databricks-pyspark/databricks-pyspark-schema/internal-v1/emp_1.csv')

# %%
df.printSchema()

# %%
display(df)
