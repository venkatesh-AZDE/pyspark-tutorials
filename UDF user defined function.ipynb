# %%
data = [
    ("sales",10),
    ("market",20),
    ("hr",30),
    ("admin",40)

]

df = spark.createDataFrame(data,["dept","dept_id"])
df.show()

# %%
def add_on(value):
    return value + 10

df = df.withColumn("dept_id_new", add_on(df.dept_id))
df.show()
