# %%
df = spark.read.format("delta").load("/Volumes/databricks-pyspark/databricks-pyspark-schema/internal-v1/output/small_files/")

# %%
table_path = "`databricks-pyspark`.`databricks-pyspark-schema`.small_files_table"
df.write.format("delta").mode("overwrite").saveAsTable(table_path)

# %%
path_read ="/Volumes/databricks-pyspark/databricks-pyspark-schema/internal-v1/output/small_files/"

# %%
# %sql
CREATE TABLE employee
USING DELTA
LOCATION '/Volumes/databricks-pyspark/databricks-pyspark-schema/internal-v1/output/small_files/'

# %%
# %sql
CREATE TABLE employee
USING DELTA
LOCATION '/Volumes/databricks-pyspark/databricks-pyspark-schema/internal-v1/output/small_files';
